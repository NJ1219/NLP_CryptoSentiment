# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nites\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv("API_KEYS.env")
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch all the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_news['totalResults']}")
# Out:
# Total articles about Bitcoin: 4383

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Ethereum: {ethereum_news['totalResults']}")
# Out:
# Total articles about Ethereum: 1259

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head(20)
# Out:
#                     date                                               text  \
# 0   2020-07-31T18:33:02Z  Authorities in Tampa, Florida have arrested a ...
# 1   2020-08-06T18:25:29Z  Casa, a Colorado-based provider of bitcoin sec...
# 2   2020-08-01T00:12:01Z  On July 15, a Discord user with the handle Kir...
# 3   2020-08-03T14:02:34Z  In April, the Secret Service seized 100 Bitcoi...
# 4   2020-08-06T16:16:32Z  The question still remained, though, whether a...
# 5   2020-08-04T20:30:00Z  A ransomware variant called NetWalker is doing...
# 6   2020-07-31T20:11:00Z  Earlier this month a number of Twitter account...
# 7   2020-07-31T18:58:34Z  Hillsborough State Attorney Andrew Warren anno...
# 8   2020-08-23T12:19:36Z  “The COVID-19 pandemic has resulted in a mass ...
# 9   2020-07-31T19:18:25Z  (CNN)A teenager in Tampa was arrested and char...
# 10  2020-08-07T20:22:54Z  In what appears to be a massive coordinated st...
# 11  2020-07-31T19:33:55Z  Image caption\r\n Elon Musk, Kim Kardashian an...
# 12  2020-08-17T15:59:00Z  LONDON (Reuters) - Bitcoin jumped to its highe...
# 13  2020-08-26T09:41:43Z  Our robot colleague Satoshi Nakaboto writes ab...
# 14  2020-08-17T08:59:41Z  Our robot colleague Satoshi Nakaboto writes ab...
# 15  2020-08-20T08:55:11Z  Our robot colleague Satoshi Nakaboto writes ab...
# 16  2020-07-29T09:18:54Z  Our robot colleague Satoshi Nakaboto writes ab...
# 17  2020-08-05T15:30:00Z  Pranksters disrupted judicial hearings on Wedn...
# 18  2020-08-26T00:00:57Z  FTX, a cryptocurrency exchange that offers der...
# 19  2020-08-14T20:27:28Z  Posted \r\nGeorge Ball, now CEO of Sanders Mor...
#
#     compound  positive  negative  neutral
# 0    -0.4767     0.000     0.094    0.906
# 1     0.5994     0.149     0.000    0.851
# 2    -0.4019     0.000     0.074    0.926
# 3     0.0000     0.000     0.000    1.000
# 4    -0.0516     0.065     0.071    0.864
# 5     0.5106     0.122     0.000    0.878
# 6     0.6249     0.184     0.000    0.816
# 7    -0.6808     0.000     0.157    0.843
# 8     0.2732     0.063     0.000    0.937
# 9    -0.0258     0.118     0.120    0.762
# 10   -0.1280     0.000     0.046    0.954
# 11   -0.6597     0.000     0.144    0.856
# 12    0.3818     0.069     0.000    0.931
# 13    0.5070     0.090     0.000    0.910
# 14    0.5070     0.090     0.000    0.910
# 15    0.5070     0.090     0.000    0.910
# 16    0.5070     0.090     0.000    0.910
# 17    0.3182     0.073     0.000    0.927
# 18    0.7506     0.198     0.000    0.802
# 19    0.6124     0.139     0.000    0.861

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head(20)
# Out:
#                     date                                               text  \
# 0   2020-08-17T04:00:00Z  TL;DR: The Mega Blockchain Mastery Bundle is o...
# 1   2020-08-26T06:07:00Z  LONDON (Reuters) - It sounds like a surefire b...
# 2   2020-08-25T13:01:00Z  NEW YORK (Reuters) - Brooklyn-based technology...
# 3   2020-08-19T07:04:25Z  An outspoken Bitcoin whale who rarely shows af...
# 4   2020-08-14T20:13:44Z  REUTERS/Rick Wilking\r\n<ul><li>Michael Novogr...
# 5   2020-08-04T16:00:00Z  August\r\n4, 2020\r\n5 min read\r\nOpinions ex...
# 6   2020-07-29T11:31:02Z  Crypto has been on a tear in the last week.\r\...
# 7   2020-07-30T09:15:36Z  Our robot colleague Satoshi Nakaboto writes ab...
# 8   2020-08-11T13:46:23Z  Ethereum is one of the most growing cryptocurr...
# 9   2020-08-04T15:00:30Z  Ethereum 2.0s final and official public testne...
# 10  2020-08-02T21:11:42Z  On Aug. 2, the price of Ethereum peaked at $41...
# 11  2020-08-03T21:15:45Z  usa one hundred dollar banknotes among the bin...
# 12  2020-07-31T03:00:05Z  Five years ago this week, the first general-pu...
# 13  2020-08-10T16:35:09Z  Last week, hackers took control of several pop...
# 14  2020-08-12T20:29:35Z  Bitcoin is making up for lost gains after hitt...
# 15  2020-08-17T19:59:00Z  What happened\r\nThe stock market was nearly f...
# 16  2020-08-06T16:00:13Z  Rally is launching a cryptocurrency dubbed Cre...
# 17  2020-08-04T20:21:07Z  Bitcoin trading is weak Tuesday while volumes ...
# 18  2020-08-01T13:00:00Z  DeFi Dad is a DeFi super user sharing his mone...
# 19  2020-07-29T10:00:48Z  Ethereum has attracted the attention of large ...
#
#     compound  positive  negative  neutral
# 0     0.0000     0.000     0.000    1.000
# 1     0.7579     0.181     0.000    0.819
# 2     0.0000     0.000     0.000    1.000
# 3    -0.2677     0.045     0.074    0.881
# 4     0.3400     0.072     0.000    0.928
# 5     0.5423     0.123     0.000    0.877
# 6     0.0000     0.000     0.000    1.000
# 7     0.5070     0.090     0.000    0.910
# 8     0.2484     0.057     0.000    0.943
# 9     0.0000     0.000     0.000    1.000
# 10   -0.2732     0.000     0.052    0.948
# 11    0.0000     0.000     0.000    1.000
# 12    0.3182     0.069     0.000    0.931
# 13   -0.1027     0.129     0.139    0.732
# 14   -0.5994     0.062     0.189    0.749
# 15    0.0000     0.000     0.000    1.000
# 16    0.4019     0.080     0.000    0.920
# 17   -0.4404     0.000     0.075    0.925
# 18    0.7717     0.165     0.000    0.835
# 19    0.4215     0.078     0.000    0.922

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.062778    0.062990    0.05484    0.882210
# std      0.470783    0.055188    0.07609    0.080684
# min     -0.897900    0.000000    0.00000    0.588000
# 25%     -0.296000    0.000000    0.00000    0.843000
# 50%      0.051500    0.069500    0.00000    0.910000
# 75%      0.507000    0.090000    0.08900    0.927000
# max      0.788900    0.216000    0.31400    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  96.000000  96.000000  96.000000  96.000000
# mean    0.090894   0.060698   0.042625   0.896687
# std     0.416367   0.064925   0.064718   0.083698
# min    -0.910000   0.000000   0.000000   0.691000
# 25%    -0.102700   0.000000   0.000000   0.848000
# 50%     0.000000   0.060000   0.000000   0.912000
# 75%     0.421500   0.090250   0.072000   0.952000
# max     0.817600   0.270000   0.309000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin has the higher Mean Positive Score of .063 as compared to .061 of Ethereum.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the higher Compound Score of .817 (Max Compound) as compared to .789 of Bitcoin.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the higher Positive Score of .270 (Max Positive) as compared to .261 of Bitcoin.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nites\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Complete the tokenizer function

lemmatizer = WordNetLemmatizer()

def tokenizer(text):
    """Tokenizes text and returns a list of words that is 
    lemmatized, stopworded, tokenized, and free of any non-letter characters. """
    
    # Create a list of the words
    regex = re.compile("[^a-zA-Z ]")
    
    # Remove the punctuation
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    
    # Remove the stop words
    sw = set(stopwords.words('english'))
    
    # Lemmatize Words into root words
    
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df["text"].apply(tokenizer)
bitcoin_df.head()
# Out:
#                    date                                               text  \
# 0  2020-07-31T18:33:02Z  Authorities in Tampa, Florida have arrested a ...
# 1  2020-08-06T18:25:29Z  Casa, a Colorado-based provider of bitcoin sec...
# 2  2020-08-01T00:12:01Z  On July 15, a Discord user with the handle Kir...
# 3  2020-08-03T14:02:34Z  In April, the Secret Service seized 100 Bitcoi...
# 4  2020-08-06T16:16:32Z  The question still remained, though, whether a...
#
#    compound  positive  negative  neutral  \
# 0   -0.4767     0.000     0.094    0.906
# 1    0.5994     0.149     0.000    0.851
# 2   -0.4019     0.000     0.074    0.926
# 3    0.0000     0.000     0.000    1.000
# 4   -0.0516     0.065     0.071    0.864
#
#                                               tokens
# 0  [authorities, tampa, florida, arrested, yearol...
# 1  [casa, coloradobased, provider, bitcoin, secur...
# 2  [july, discord, user, handle, kirk, made, enti...
# 3  [april, secret, service, seized, bitcoins, cla...
# 4  [question, still, remained, though, whether, g...

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df["text"].apply(tokenizer)
ethereum_df.head()
# Out:
#                    date                                               text  \
# 0  2020-08-17T04:00:00Z  TL;DR: The Mega Blockchain Mastery Bundle is o...
# 1  2020-08-26T06:07:00Z  LONDON (Reuters) - It sounds like a surefire b...
# 2  2020-08-25T13:01:00Z  NEW YORK (Reuters) - Brooklyn-based technology...
# 3  2020-08-19T07:04:25Z  An outspoken Bitcoin whale who rarely shows af...
# 4  2020-08-14T20:13:44Z  REUTERS/Rick Wilking\r\n<ul><li>Michael Novogr...
#
#    compound  positive  negative  neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.7579     0.181     0.000    0.819
# 2    0.0000     0.000     0.000    1.000
# 3   -0.2677     0.045     0.074    0.881
# 4    0.3400     0.072     0.000    0.928
#
#                                               tokens
# 0  [tldr, mega, blockchain, mastery, bundle, sale...
# 1  [london, reuters, sound, like, surefire, bet, ...
# 2  [new, york, reuters, brooklynbased, technology...
# 3  [outspoken, bitcoin, whale, rarely, show, affe...
# 4  [reutersrick, wilkingullimichael, novogratz, t...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_ngrams = []
for list in bitcoin_df.tokens:
    bitcoin_ngrams += list
        

bigram_counts_btc = Counter(ngrams(bitcoin_ngrams, n=2))
print(dict(bigram_counts_btc.most_common(10)))
# Out:
# {('satoshi', 'nakaboto'): 44, ('char', 'robot'): 22, ('robot', 'colleague'): 22, ('colleague', 'satoshi'): 22, ('nakaboto', 'writes'): 22, ('writes', 'bitcoin'): 22, ('every', 'fucking'): 22, ('fucking', 'daywelcome'): 22, ('daywelcome', 'another'): 22, ('another', 'edition'): 22}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_ngrams = []
for list in ethereum_df.tokens:
    ethereum_ngrams += list
        

bigram_counts_eth = Counter(ngrams(ethereum_ngrams, n=2))
print(dict(bigram_counts_eth.most_common(10)))
# Out:
# {('char', 'ethereum'): 17, ('decentralized', 'finance'): 10, ('ethereum', 'classic'): 10, ('finance', 'defi'): 8, ('ethereum', 'blockchain'): 7, ('char', 'bitcoin'): 5, ('btc', 'trading'): 5, ('trading', 'around'): 5, ('char', 'decentralized'): 4, ('char', 'eoseos'): 4}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(10)

# %%
# Get the top 10 words for Bitcoin
token_count(bitcoin_ngrams)
# Out:
# [('char', 98),
#  ('bitcoin', 86),
#  ('satoshi', 44),
#  ('nakaboto', 44),
#  ('twitter', 28),
#  ('today', 24),
#  ('another', 23),
#  ('tell', 23),
#  ('robot', 22),
#  ('colleague', 22)]

# %%
# Get the top 10 words for Ethereum
token_count(ethereum_ngrams)
# Out:
# [('char', 96),
#  ('ethereum', 57),
#  ('ha', 30),
#  ('blockchain', 25),
#  ('bitcoin', 19),
#  ('network', 19),
#  ('defi', 15),
#  ('wa', 14),
#  ('decentralized', 14),
#  ('exchange', 14)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string_btc = ' '.join(bitcoin_ngrams)
wc = WordCloud().generate(big_string_btc)
plt.axis("off")
plt.title("Bitcoin Word Cloud")
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
big_string_eth = ' '.join(ethereum_ngrams)
wc = WordCloud().generate(big_string_eth)
plt.axis("off")
plt.title("Ethereum Word Cloud")
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = " ".join(bitcoin_df.text.to_list())

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_text)


# Add a title to the document
btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Authorities in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tampa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  have arrested a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for being the alleged “mastermind” behind the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  hack that targeted several high-profile accounts on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 15th, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . His name h… [+463 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Casa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1571 chars] On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Discord
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  user with the handle Kirk#5270 made an enticing proposition. I work for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , they said, according to court documents released
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . I can claim any name, let me know if yo… [+3660 chars] In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seized
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , NYT reports.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weeks later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bennett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  received a letter explaining that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had recovered
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of his Bitcoins. The letter cited… [+884 chars] The question still remained, though, whether all that GPU-crunching would actually work. After
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span

# %%
# List all Entities
for ent in btc_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Tampa GPE
# Florida GPE
# 17-year-old DATE
# Twitter Bitcoin ORG
# July 15th, 2020 DATE
# Casa PERSON
# Colorado GPE
# Coinbas ORG
# July 15 DATE
# Discord GPE
# Twitter ORG
# Friday DATE
# April DATE
# the Secret Service ORG
# 100 CARDINAL
# Bitcoins ORG
# Clark GPE
# Weeks later DATE
# Bennett PERSON
# the Secret Service ORG
# 100 CARDINAL
# months DATE
# Guy PERSON
# NetWalker ORG
# Bitcoin GPE
# $25 million MONEY
# the last five DATE
# Earlier this month DATE
# Twitter ORG
# Elon Musk PERSON
# Joe Biden PERSON
# Barack Obama PERSON
# Bill Gates PERSON
# Jeff Bezos PERSON
# Andrew Warren PERSON
# today DATE
# 30 CARDINAL
# 17-year-old DATE
# Tampa GPE
# Florida GPE
# VPN PRODUCT
# Tampa GPE
# Friday DATE
# Twitter ORG
# earlier this month DATE
# Joe Biden PERSON
# Bill G PERSON
# Reddit ORG
# over dozens CARDINAL
# Friday DATE
# afternoon TIME
# pro-Donald Trump PERSON
# Kim Kardashian PERSON
# Barack Obama PERSON
# Florida GPE
# Twitter ORG
# July DATE
# the Hillsborough Stat WORK_OF_ART
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# over a year DATE
# Monday DATE
# 2020 DATE
# March DATE
# 4.4% PERCENT
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Wednesday DATE
# 17-year-old DATE
# Florida GPE
# Twitter ORG
# last month DATE
# Blockfolio GPE
# FTX ORG
# $150 million MONEY
# George Ball PERSON
# Sanders Morris Harris ORG
# Bitcoin GPE
# Fred Katayama PERSON
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Reuters ORG
# ul><li PERSON
# JPMorgan ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Rick Wilking PERSON
# ul><li PERSON
# Michael Novogratz PERSON
# Bloomberg PERSON
# up to $3,000 MONEY
# The Galaxy Digital ORG
# Fed ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# August DATE
# 17, 2020 DATE
# 6 min QUANTITY
# Tim Draper PERSON
# Draper Fisher Jurvetson ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Grayscale Bitcoin BTC Trust FAC
# GBTC ORG
# Bitcoin GPE
# $1.5 billion MONEY
# this year DATE
# 90% PERCENT
# just six months DATE
# Stanford ORG
# Alexander Liegl PERSON
# Liegl PERSON
# Peter Thiel PERSON
# Florida Man PERSON
# Florida Teen PERSON
# 17-year-old DATE
# Tampa GPE
# Florida GPE
# July 15 DATE
# Twitter ORG
# 29.81 MONEY
# August 17 DATE
# 97% PERCENT
# 45 CARDINAL
# 36 CARDINAL
# seven CARDINAL
# Twitter ORG
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# SpaceX CARDINAL
# NASA ORG
# last week DATE
# first ORDINAL
# millions CARDINAL
# YouTube PRODUCT
# Earth LOC
# Tens of thousands CARDINAL
# August 6 DATE
# Overnight TIME
# Bitcoin GPE
# Front Page Tech WORK_OF_ART
# 100,000 CARDINAL
# this week DATE
# first ORDINAL
# YouTube PRODUCT
# US GPE
# three CARDINAL
# Twitter ORG
# this month DATE
# Xcode ORG
# Trend Micro ORG
# Twitter ORG
# two weeks ago DATE
# Twitter ORG
# Apple ORG
# Last week DATE
# YouTube PRODUCT
# Bitcoin GPE
# Richard Stallman PERSON
# Cointelegraph ORG
# more than $100,000 MONEY
# Bitcoin GPE
# Clark PERSON
# one single day DATE
# ten CARDINAL
# fiat ORG
# LONDON GPE
# Florida GPE
# Twitter ORG
# more than $100,000 MONEY
# Bitcoin GPE
# Joe Sullivan PERSON
# U.S. GPE
# the United States District Court GPE
# the Northern District LOC
# TAMPA ORG
# Tampa GPE
# Twitter ORG
# more than $100,000 MONEY
# Bitcoin GPE
# Graham Ivan Clark PERSON
# 17 CARDINAL
# Elon Musk ORG
# Tesla ORDINAL
# Thursday DATE
# Russian NORP
# Bitfinex PERSON
# $400 million MONEY
# $1.33 billion MONEY
# Bitcoin BTCstolen FAC
# 2016 DATE
# Bitfinex PERSON
# 17-year-old DATE
# Tampa GPE
# Florida GPE
# FBI ORG
# IRS ORG
# US Secret Service ORG
# Florida GPE
# Bitcoin GPE
# Twitter ORG
# Lincolnshire GPE
# two CARDINAL
# three CARDINAL
# two CARDINAL
# Tesco ORG
# Nigel Wright PERSON
# Market Rasen PERSON
# Florida GPE
# Friday DATE
# 30 CARDINAL
# last month's DATE
# Twitter ORG
# Twitter ORG
# Andrew Warren PERSON
# 17-year-old DATE
# Tampa GPE
# Florida GPE
# Friday DATE
# Twitter ORG
# earlier this month DATE
# dozens CARDINAL
# US GPE
# LONDON GPE
# Reuters ORG
# U.S. GPE
# CWT ORG
# $4.5 million MONEY
# this week DATE
# 30,000 CARDINAL
# LONDON GPE
# Reuters ORG
# U.S. GPE
# CWT ORG
# $4.5 million MONEY
# this week DATE
# 30,000 CARDINAL
# Less than two weeks DATE
# Twitter PERSON
# Elon Musk ORG
# Barrack Obama PERSON
# WIRE)--Aug DATE
# 11 DATE
# MSTR PERSON
# today DATE
# Graham Ivan Clark PERSON
# 17 DATE
# Twitter ORG
# Florida GPE
# last months DATE
# Twitterbitcoin DATE
# Reuters ORG
# 17-year-old DATE
# Florida GPE
# Twitter Inc ORG
# Democratic NORP
# Joe Biden PERSON
# Reuters ORG
# 17-year-old DATE
# Florida GPE
# Twitter Inc ORG
# Democratic NORP
# Joe Biden PERSON
# WASHINGTON GPE
# Reuters ORG
# Uber Technologies ORG
# Thursday DATE
# 2016 DATE
# about 57 mi CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Two and a half years ago DATE
# Kim Kardashian PERSON
# Kanye West GPE
# five CARDINAL
# 500,000 MONEY
# Kardashians NORP
# Twitter PERSON
# Android app PERSON
# Android PERSON
# 2018 DATE
# Twitter ORG
# mid-July DATE
# Twitter ORG
# Angela Lang PERSON
# Twitter ORG
# earlier this month DATE
# dozens CARDINAL
# Mike Stay PERSON
# 300,000 MONEY
# bitcoin GPE
# July DATE
# three CARDINAL
# US GPE
# UK GPE
# Twitter ORG
# earlier this month DATE
# Twitter ORG
# Thursday DATE
# Knibbeler PERSON
# 'Current Studies' WORK_OF_ART
# 2013-2016 DATE
# WASHINGTON GPE
# Reuters ORG
# The U.S. Justice Department ORG
# Thursday DATE
# Hamas ORG
# al Qaeda ORG
# Islamic State ORG
# 17-year-old DATE
# Graham Ivan Clark PERSON
# 30 CARDINAL
# Twitter ORG
# dozens CARDINAL
# over $10 MONEY
# TNW Basics ORG
# Gmail PERSON
# HONG KONG/NEW YORK GPE
# Reuters ORG
# Asian NORP
# Tuesday DATE
# Sino NORP
# Tampa GPE
# Florida GPE
# 17-year-old DATE
# Graham Clark PERSON
# early Friday TIME
# morning TIME
# Twitter ORG
# earlier this month DATE
# The July 15 DATE
# Sullivan LOC
# up to eight years DATE
# Square Inc. ORG
# Wednesday DATE
# the second quarter DATE
# a day DATE
# Baltimore GPE
# Dominic DiPietro PERSON
# 17 year-old DATE
# Tampa GPE
# Florida GPE
# Twitter ORG
# Florida GPE
# 30 CARDINAL
# Graham Clar PERSON
# the past few years DATE
# the past few years DATE
# the past few years DATE
# just one CARDINAL
# just one CARDINAL
# the past few years DATE
# just one CARDINAL

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = " ".join(ethereum_df.text.to_list())

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text)


# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">TL;DR: The Mega Blockchain Mastery Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.81
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Cash isn't necessarily king anymore. You've probably heard that cryptocurrency and bloc… [+1286 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 20%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . What could possibly g… [+7143 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEW YORK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based technology startup
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConsenSys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has acquired
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan Chase &amp;amp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; Co’s (JPM.N) marquee blockchain platform
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quorum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the companies said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>As part of the dea… [+1915 chars] An outspoken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whale who rarely shows affection for anything other than
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The pseudonymous trader known as Joe007 says
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNUS SED LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) may be a soli… [+1503 chars] REUTERS/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick Wilking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>&lt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ul&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &gt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Novogratz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold;

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# 29.81 MONEY
# August 17 DATE
# 97% PERCENT
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# NEW YORK PERSON
# Reuters ORG
# Brooklyn GPE
# ConsenSys ORG
# JPMorgan Chase &amp ORG
# Quorum PRODUCT
# Tuesday DATE
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# Rick Wilking PERSON
# ul><li PERSON
# Michael Novogratz PERSON
# Bloomberg PERSON
# up to $3,000 MONEY
# The Galaxy Digital ORG
# Fed ORG
# August DATE
# 4 DATE
# 2020 DATE
# 5 CARDINAL
# Crypto PERSON
# the last week DATE
# Bitcoin GPE
# 18% PERCENT
# the last seven days DATE
# over 30% PERCENT
# the last week DATE
# first ORDINAL
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# first ORDINAL
# Medalla PERSON
# the Ethereum Foundation ORG
# ul><li PERSON
# Medalla GPE
# Aug. 2 DATE
# 418 MONEY
# 5 minutes TIME
# 25% PERCENT
# Binance Futures ORG
# ETH ORG
# as low as $302 MONEY
# 385 MONEY
# 10 minutes TIME
# one hundred dollar MONEY
# Fintech ORG
# Five years ago this week DATE
# first ORDINAL
# Bitcoins ORG
# Last week DATE
# YouTube PRODUCT
# Bitcoin GPE
# Bitcoin GPE
# one-week DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,595 MONEY
# 20:0 CARDINAL
# Monday DATE
# 500 CARDINAL
# less than 1% PERCENT
# 3 p.m. EDT TIME
# Ho PERSON
# Rally PERSON
# Creator Coin PERSON
# Creator Coin PERSON
# Bitcoin GPE
# Tuesday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,2587 as of 20:00 MONEY
# 4 p.m. ET TIME
# 1.6% PERCENT
# DeFi Dad PERSON
# Twitter ORG
# YouTube PERSON
# the Ethereal Summit and Sessions ORG
# The Ethereal Podcast ORG
# early 2017 DATE
# Enterpri ORG
# DeFi LOC
# this weekend DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,579 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 2.4% PERCENT
# Silicon Valley LOC
# cLabs ORG
# DeFi ORG
# Shirely Lara PERSON
# CoinDesk PERSON
# Leigh Cuen PERSON
# Mondays DATE
# $7 million MONEY
# the past month DATE
# ul><li GPE
# Bitcoin GPE
# BTC ORG
# around $12,00 MONEY
# Bitcoin GPE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,298 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 3.8% PERCENT
# late last week DATE
# another 51% PERCENT
# early Thursday TIME
# morning TIME
# WarGames ORG
# 1983 DATE
# Matthew Broderick PERSON
# U.S. GPE
# 2015 DATE
# DeFi ORG
# Geth PERSON
# 27 months DATE
# daily DATE
# 3 p.m. Eastern TIME
# Apple Podcasts, Spo WORK_OF_ART
# Matic Network ORG
# $5 million MONEY
# DeFi ORG
# ul><li PERSON
# Ma PERSON
# Ethereum Classic PRODUCT
# Instagram PRODUCT
# Bitmain GPE
# Blockchain Bites WORK_OF_ART
# Gavin Wood PERSON
# Ethereums 2015 LOC
# second ORDINAL
# nearly a quarter DATE
# the Tor Network ORG
# Bitcoin GPE
# Twitter ORG
# Friday DATE
# 2016 DATE
# $55 million MONEY
# Tuesday DATE
# CoinDesk Live PERSON
# Cornell PERSON
# Audius PERSON
# $3.1 million MONEY
# Multicoin Capital ORG
# Blockchange NORP
# the U.S. Securities and Exchange Commission ORG
# SEC ORG
# Mason Borda ORG
# DisclosureThe ORG
# CoinDesk PRODUCT
# Tether PERSON
# Tether PERSON
# DEFI ORG
# INX ORG
# 1 billion CARDINAL
# Tron to Ethereum ORG
# bitcoin GPE
# Blockchai GPE
# Quorum PRODUCT
# JPMorgan Chase ORG
# ConsenSys ORG
# Brooklyn GPE
# JPMorgan ORG
# un ORG
# DeFi ORG
# DeFi Pulse PERSON
# 1.47 MONEY
# last month DATE
# the U.S. Office of the Comptroller of the Currency ORG
# OCC ORG
# Version 1.0 PRODUCT
# Wednesday DATE
# Micr PERSON
# Ethereum Classics ORG
# January DATE
# two CARDINAL
# 51% PERCENT
# August DATE
# One CARDINAL
# 2020 DATE
# DeFi ORG
# July DATE
# DG Lab ORG
# approximately $5.6 million MONEY
# Ethereum Classic GPE
# ETC ORG
# two CARDINAL
# 51% PERCENT
# Chainlink ORG
# Arbol ORG
# Arbol ORG
# DeFi PERSON
# Protocol PRODUCT
# Polkadot ORG
# weeks DATE
# today DATE
# developer house Snowfork ORG
# 13% PERCENT
# First ORDINAL
# May and June DATE
# GitHub ORG
# Bitcoin GPE
# BTC ORG
# Monday DATE
# 2020 CARDINAL
# above $12,400 MONEY
# Ethereum Classic FAC
# Blockchain Bites WORK_OF_ART
# daily DATE
# as many as 15 CARDINAL
# OMG Network ORG
# the past week DATE
# CoinGecko ORG
# Leah Callon-Butler PERSON
# Emfarsis ORG
# Asia LOC
# the early 1980s DATE
# zero CARDINAL
# second ORDINAL
# 51% PERCENT
# a week DATE
# Thursday DATE
# morning TIME
# more than 4,000 CARDINAL
# bitcoin rises GPE
# Dot ORG
# Ouriel Ohayon PERSON
# 2017 DATE
# Ava Labs ORG
# Cornel PERSON
# 1.36% PERCENT
# Friday DATE
# 0.90% PERCENT
# Thursday DATE
# the month DATE
# 30.56% PERCENT
# 3.0950 MONEY
# the day DATE
# early morning TIME
# 500,000 MONEY
# ul><li PERSON
# Monday DATE
# FBG Capital ORG
# NGC Ventures ORG
# Asia LOC
# Litecoin Litecoin PERSON
# Charlie Lee PERSON
# The Litecoin Network ORG
# every 2.5 minutes TIME
# Bitcoin GPE
# 10 m CARDINAL
# Ethereum Classic ORG
# 51% PERCENT
# Saturday DATE
# evening TIME
# third ORDINAL
# 51% PERCENT
# this month DATE
# Bitfly ORG
# first ORDINAL
# Aug. 1 DATE
# ul><li PERSON
# 3.58% PERCENT
# Monday DATE
# Sundays DATE
# 10.93% PERCENT
# the day DATE
# 3.0463 MONEY
# the day DATE
# early morning TIME
# low $2.9022 MONEY
# bef PERSON
# East LOC
# five CARDINAL
# CoinDesk’s Markets Daily ORG
# Crypto ORG
# Grayscale ORG
# Ethereum Trust ORG
# Securities and Exchange Commission ORG
# SEC ORG
# Thursday DATE
# $143.8 million MONEY
# July DATE
# 23-month DATE
# The Block Research ORG
# nearly 23% PERCENT
# The Ethereum Classic ORG
# ETC ORG
# a second 51% PERCENT
# a week DATE
# Ethermine ORG
# Thursday DATE
# morning TIME
# Yahoo ORG
# de Verizon PERSON
# Cliquez ORG
# sur J'accepte PRODUCT
# Verizon Media PRODUCT
# RenVM DeFi LOC
# more than 100% PERCENT
# the past week DATE
# RenVM GPE
# 10,000 CARDINAL
# Five years ago this week DATE
# first ORDINAL
# Bitcoins ORG
# Ethereum 2.0 ORG
# ETH ORG
# Fall 2020 DATE
# 5-10% PERCENT
# $1 billion MONEY
# 2017 DATE
# 7.77% PERCENT
# Tuesday DATE
# 1.99% PERCENT
# Monday DATE
# the day DATE
# 3.1234 MONEY
# the day DATE
# early morning TIME
# 3.3961 MONEY
# 4.11% PERCENT
# Sunday DATE
# 14% PERCENT
# Saturday DATE
# the week DATE
# 28.09% PERCENT
# 3.8792 MONEY
# the day DATE
# early morning TIME
# 3.8724 MONEY
# Litecoin Litecoin PERSON
# Charlie Lee PERSON
# The Litecoin Network ORG
# every 2.5 minutes TIME
# Bitcoin GPE
# 10 m CARDINAL
# Bitcoin GPE
# 12% and 20% PERCENT
# about 6 minutes TIME
# more than $1 billion MONEY
# 11,930 MONEY
# 10,550 MONEY
# Ethereum Classic ORG
# 3,693 CARDINAL
# first ORDINAL
# Binance ORG
# one CARDINAL
# Digital ORG
# Ethereum Classic ORG
# Wednesday DATE
# 51% PERCENT
# recent weeks DATE
# Ethereum Classic PRODUCT
# CryptoSafe Alliance ORG
# Oasis Labs ORG
# ul><li PERSON
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# Tether PERSON
# today DATE
# 1 billion USDT MONEY
# 8% PERCENT
# TRON ORG
# Tether PERSON
# Paolo Ardoino PERSON
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# second ORDINAL
# 51% PERCENT
# Thursday DATE
# 4,236 CARDINAL
# $1.68 million MONEY
# bitcoin GPE
# 12 MONEY
# CoinDesk’s Markets Daily ORG
# Ap PERSON
# EBON PERSON
# Friday DATE
# DeFi ORG
# Acala PERSON
# DeFi LOC
# Polkadot LOC
# $7 million MONEY
# 18 MONEY
# 16.88 MONEY
# fifth ORDINAL

# %% [markdown]
# ---
